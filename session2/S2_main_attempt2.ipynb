# %% [markdown]
# ## Build network using pretrained MobileNet_V2 architecture for Self created Drone dataset

# %%
# mount gdrive
mount_drive = True
if mount_drive:
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch

# check the allocation manhine
isCuda = torch.cuda.is_available()
machine = torch.cuda.get_device_properties(0) if isCuda else 'cpu'
print("Assigned Machine: ", machine)
device = torch.device('cuda:0' if isCuda else 'cpu')
print(f"cuda avaiable: {isCuda}, Device: {device}")
# Out:
# Assigned Machine:  _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
# cuda avaiable: True, Device: cuda:0

# %%
import os
os.chdir('/content/gdrive/My Drive/TSAI/EVA4_Phase2/session2/')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/TSAI/EVA4_Phase2/session2

# %%
# Import standard packages
import torchvision
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pkgutil
import importlib

# install "apex" model for mixed precision training if required.. this is needed for LRFinder
if pkgutil.find_loader("apex") is None:
   print("apex module does not exist")
   # !pip install -U git+https://www.github.com/NVIDIA/apex --no-cache-dir

from utils.lr_finder import LRFinder # cutom module for LR finder

# %%
# To autoreload all te custom files when modified
import autoreload
# %load_ext autoreload
# %autoreload

# %%
#import shutil
#shutil.rmtree('./logs_v2')

# %%
from pathlib import Path

# important folders used in this application

SOLUTION_LOG_DIR = "logs_v2"     # root directoy for all the log of this notebook
Path(f'./{SOLUTION_LOG_DIR}').mkdir(exist_ok=True)

SAVED_MODELS_DIR = Path(f'./{SOLUTION_LOG_DIR}/saved_models') # location to save models
SAVED_MODELS_DIR.mkdir(exist_ok=True)

SAVED_RESULTS_DIR = Path(f'./{SOLUTION_LOG_DIR}/saved_results')
SAVED_RESULTS_DIR.mkdir(exist_ok=True)

PLOT_DIR = Path(f'./{SOLUTION_LOG_DIR}/doc_images')
PLOT_DIR.mkdir(exist_ok=True)

# %%
from utils.common_utils import LR_UPDATE_TY

# Application specific configurations
config_params = dict(
    seed=1,
    batch_size=128,
    num_workers=6,
    epochs=30,
    lr_update_ty=LR_UPDATE_TY.EPOCHWISE,
    resume_training = False,
    load_model_path = Path(f'./{SAVED_MODELS_DIR}/ep2_testloss_1.160373000.pth'), # used when resume_training is True
)

torch.manual_seed(config_params['seed'])
if isCuda:
   torch.cuda.manual_seed(config_params['seed'])

# %%
# dataset path where zip files are placed
src_dataset_dir = '/content/gdrive/My Drive/TSAI/EVA4_Phase2/datasets/s2_dataset/'
#src_dataset_dir = '/content/gdrive/My Drive/TSAI/EVA4_Phase2/datasets/session2/s2_dataset_v1/'

#unzip locations: note path shall be colab internal memory location not on mounted drive.
root_dataset = '/content/eva4p2_s2_dataset_v1'

# %%
import shutil
#shutil.rmtree(root_dataset)

# %%
class_list = ['Flying Birds', 'Large QuadCopters', 'Small QuadCopters', 'Winged Drones']
class_list_shortname = ['FB', 'LQC', 'SQC', 'WD']

# %% [markdown]
# # Preparing Dataset

# %%
# Extracting zipped dataset into colab internal memory
# %%time

import zipfile
def extract_dataset(fn, dest):
    with open(fn, 'rb') as f:
      zf = zipfile.ZipFile(f)
      zf.extractall(dest)
      
# create root destination folder
if not Path(root_dataset).exists():
  Path(root_dataset).mkdir(exist_ok=True)

# extract individual class zip file
for classname in class_list:
  class_zipname = f'{src_dataset_dir}/{classname}.zip'  
  class_dir = f'{root_dataset}/{classname}' # class folder unzip location
  if not Path(class_dir).exists():
    print(f'Extracting {classname} images...')
    extract_dataset(fn=class_zipname, dest=class_dir)
# Out:
# CPU times: user 109 µs, sys: 0 ns, total: 109 µs
# Wall time: 113 µs

# %%
# dataset count-summary
def get_dataset_count(roordir, classlist):
    total = 0
    for classname in classlist:
      classdir = os.path.join(roordir, classname)
      classcnt = len(os.listdir(classdir))
      total += classcnt
      print(f'{classname}: {classcnt} images')

    print(f'\nTotal images: {total}')
    return

def display_classnames(shortname_list, fullname_list):
  for shortname, fullname in zip(shortname_list, fullname_list):
    print(f'{shortname}: {fullname}')

# %%
get_dataset_count(root_dataset, class_list)
# Out:
# Flying Birds: 7931 images
# Large QuadCopters: 4003 images
# Small QuadCopters: 3306 images
# Winged Drones: 4189 images
#
# Total images: 19429

# %% [markdown]
# # Remove all duplicate and errornous file

# %%
import pandas as pd
df_dataset = pd.read_csv('eda_duplicate_list.csv')
df_remove = df_dataset[(df_dataset['duplicate'] == 1) | (df_dataset['cross_duplicate'] == 1) | (df_dataset['errornous_file'] == 1)]
print(f'File to removes: {len(df_remove)}')
df_remove['classname'].value_counts()
# Out:
# File to removes: 2376
# Winged Drones        1486
# Flying Birds          407
# Small QuadCopters     317
# Large QuadCopters     166
# Name: classname, dtype: int64

# %%
df_remove.head()
# Out:
#                                               filename  ... duplicate_class
# 397                       Flying Birds/fb_img_0430.jpg  ...             NaN
# 470  Flying Birds/animal-photography-bird-flying-50...  ...             NaN
# 613  Flying Birds/Copy of 4d34f43aadc32f89c38c37493...  ...             NaN
# 904        Flying Birds/ZHATuKpukACkWHz5ObmLRgHaEK.jpg  ...             NaN
# 958                       Flying Birds/aFrDNzUEXrI.jpg  ...             NaN
#
# [5 rows x 7 columns]

# %%
from tqdm import tqdm
def remove_files(rootdir, df_data):
    dvalues = df_data.values
    pbar = tqdm(dvalues)
    for idx, item in enumerate(pbar):
      filename = dvalues[idx][0]
      filepath = f'{rootdir}/{filename}'  
      if Path(filepath).exists():
        os.remove(filepath)
      pbar.set_description(desc=f'Removing files..')
    return

# %%
remove_files(root_dataset, df_remove)
# Out:
# Removing files..: 100%|██████████| 2376/2376 [00:02<00:00, 986.64it/s]

# %%
# check the final dataset summary used for model building
get_dataset_count(root_dataset, class_list)
# Out:
# Flying Birds: 7931 images
# Large QuadCopters: 4003 images
# Small QuadCopters: 3306 images
# Winged Drones: 4189 images
#
# Total images: 19429

# %% [markdown]
# # Prepare Data Transforms and DataLoader

# %%
from torchvision import transforms

# Transform functions
def get_train_transform(means, stds):
    train_tf = transforms.Compose([
           transforms.Resize((224,224)),
           transforms.ColorJitter(brightness=0.10, contrast=0.10),
           #transforms.RandomRotation((-7.0, 7.0), fill(1,)),
           #transforms.RandomCrop(32, padding=4),
           transforms.RandomHorizontalFlip(),
           transforms.ToTensor(),
           transforms.Normalize(means, stds),
           transforms.RandomErasing(scale=(0.02, 0.20), ratio=(0.8, 1.2)),
           #transforms,RandomResizing(scale=(0.02, 0.20), ratio=(0.8, 1.2))                        
    ])
    return train_tf

def get_test_transform(means, stds):
    test_tf = transforms.Compose([
           transforms.Resize((224,224)),
           transforms.ToTensor(),
           transforms.Normalize(means, stds)                
    ])
    return test_tf

# %%
means, stds = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]

train_transforms = get_train_transform(means, stds)
test_transforms = get_test_transform(means, stds)

# %%
import utils.data_utils as dutils

dataloader_args = dict(shuffle=False, batch_size=config_params["batch_size"], num_workers=config_params["num_workers"], pin_memory=True) if isCuda else dict(shuffle=True, batch_size=8)

train_loader, test_loader = dutils.prepare_dataloader(datadir=root_dataset, 
                                               train_transforms=train_transforms, 
                                               test_transforms=test_transforms, 
                                               dataloader_args=dataloader_args, 
                                               valid_size=0.30)

print(f'Classes: {train_loader.dataset.classes}')
# Out:
# Total data: 19429
#
# Training size: 13601
# Testing size: 5828
# Classes: ['Flying Birds', 'Large QuadCopters', 'Small QuadCopters', 'Winged Drones']

# %% [markdown]
# # Visualize few training images

# %%
from utils.plot_utils import PlotUtils

putils = PlotUtils(device, class_list_shortname, means, stds)

# %%
# visualize how image aumentation is applied on few training dataset images: 
display_classnames(class_list_shortname, class_list)
putils.plot_dataset_images(train_loader, figsize=(15,12), save_filename=f'{PLOT_DIR}/dataset_samples.jpg')
# Out:
# FB: Flying Birds
# LQC: Large QuadCopters
# SQC: Small QuadCopters
# WD: Winged Drones

# %%
# %time
samples = next(iter(train_loader))

# Image dimension
print(f'Image size: {samples[0][0].shape}')
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# Image size: torch.Size([3, 224, 224])

# %% [markdown]
# # Pretrained MobileNet_V2 network

# %%
from torchvision.models import mobilenet_v2
model = mobilenet_v2(pretrained=True)
print(model)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvBNReLU(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ### Finetuning of Pre-trianed model. Unfreeze the last 3 blocks

# %%
def freeze_all_layers(model):
    for name, layer in model.named_modules():
        for parameter in layer.parameters():
          parameter.requires_grad = False

def unfreeze_layers_by_name(model, unfreeze_layer_name_list):
    for name, layer in model.named_modules():
      unfreeze = any(n in name for n in unfreeze_layer_name_list)
      if(unfreeze):
        for parameter in layer.parameters():
          parameter.requires_grad = True
      else:
        for parameter in layer.parameters():
          parameter.requires_grad = False

def unfreeze_layers_by_ids(model, unfreeze_layer_ids_list):
    # MobileNet_V2 have 19 features block accessible throunf name: features[idx]
    for idx in range(19):
      if idx in unfreeze_layer_ids_list:
        for param in model.features[idx].parameters():
          param.requires_grad = True
      else:
        for param in model.features[idx].parameters():
          param.requires_grad = False

def show_layers(model):
    for name, layer in model.named_modules():
      for parameter in layer.parameters():
        print(f'Layer name: {name}, Requires Grad: {parameter.requires_grad}')

# %%
unfreeze_layer_names = ['features.16', 'features.17', 'features.18', 'classifier']
unfreeze_layers_by_name(model, unfreeze_layer_names)

# %%
show_layers(model)
# Out:
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features.0, Requires Grad: False
# Layer name: features.0, Requires Grad: False
# Layer name: features.0, Requires Grad: False
# Layer name: features.0.0, Requires Grad: False
# Layer name: features.0.1, Requires Grad: False
# Layer name: features.0.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0.0, Requires Grad: False
# Layer name: features.1.conv.0.1, Requires Grad: False
# Layer name: features.1.conv.0.1, Requires Grad: False
# Layer name: features.1.conv.1, Requires Grad: False
# Layer name: features.1.conv.2, Requires Grad: False
# Layer name: features.1.conv.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0.0, Requires Grad: False
# Layer name: features.2.conv.0.1, Requires Grad: False
# Layer name: features.2.conv.0.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1.0, Requires Grad: False
# Layer name: features.2.conv.1.1, Requires Grad: False
# Layer name: features.2.conv.1.1, Requires Grad: False
# Layer name: features.2.conv.2, Requires Grad: False
# Layer name: features.2.conv.3, Requires Grad: False
# Layer name: features.2.conv.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0.0, Requires Grad: False
# Layer name: features.3.conv.0.1, Requires Grad: False
# Layer name: features.3.conv.0.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1.0, Requires Grad: False
# Layer name: features.3.conv.1.1, Requires Grad: False
# Layer name: features.3.conv.1.1, Requires Grad: False
# Layer name: features.3.conv.2, Requires Grad: False
# Layer name: features.3.conv.3, Requires Grad: False
# Layer name: features.3.conv.3, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0.0, Requires Grad: False
# Layer name: features.4.conv.0.1, Requires Grad: False
# Layer name: features.4.conv.0.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1.0, Requires Grad: False
# Layer name: features.4.conv.1.1, Requires Grad: False
# Layer name: features.4.conv.1.1, Requires Grad: False
# Layer name: features.4.conv.2, Requires Grad: False
# Layer name: features.4.conv.3, Requires Grad: False
# Layer name: features.4.conv.3, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0.0, Requires Grad: False
# Layer name: features.5.conv.0.1, Requires Grad: False
# Layer name: features.5.conv.0.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1.0, Requires Grad: False
# Layer name: features.5.conv.1.1, Requires Grad: False
# Layer name: features.5.conv.1.1, Requires Grad: False
# Layer name: features.5.conv.2, Requires Grad: False
# Layer name: features.5.conv.3, Requires Grad: False
# Layer name: features.5.conv.3, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0.0, Requires Grad: False
# Layer name: features.6.conv.0.1, Requires Grad: False
# Layer name: features.6.conv.0.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1.0, Requires Grad: False
# Layer name: features.6.conv.1.1, Requires Grad: False
# Layer name: features.6.conv.1.1, Requires Grad: False
# Layer name: features.6.conv.2, Requires Grad: False
# Layer name: features.6.conv.3, Requires Grad: False
# Layer name: features.6.conv.3, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0.0, Requires Grad: False
# Layer name: features.7.conv.0.1, Requires Grad: False
# Layer name: features.7.conv.0.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1.0, Requires Grad: False
# Layer name: features.7.conv.1.1, Requires Grad: False
# Layer name: features.7.conv.1.1, Requires Grad: False
# Layer name: features.7.conv.2, Requires Grad: False
# Layer name: features.7.conv.3, Requires Grad: False
# Layer name: features.7.conv.3, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0.0, Requires Grad: False
# Layer name: features.8.conv.0.1, Requires Grad: False
# Layer name: features.8.conv.0.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1.0, Requires Grad: False
# Layer name: features.8.conv.1.1, Requires Grad: False
# Layer name: features.8.conv.1.1, Requires Grad: False
# Layer name: features.8.conv.2, Requires Grad: False
# Layer name: features.8.conv.3, Requires Grad: False
# Layer name: features.8.conv.3, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0.0, Requires Grad: False
# Layer name: features.9.conv.0.1, Requires Grad: False
# Layer name: features.9.conv.0.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1.0, Requires Grad: False
# Layer name: features.9.conv.1.1, Requires Grad: False
# Layer name: features.9.conv.1.1, Requires Grad: False
# Layer name: features.9.conv.2, Requires Grad: False
# Layer name: features.9.conv.3, Requires Grad: False
# Layer name: features.9.conv.3, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0.0, Requires Grad: False
# Layer name: features.10.conv.0.1, Requires Grad: False
# Layer name: features.10.conv.0.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1.0, Requires Grad: False
# Layer name: features.10.conv.1.1, Requires Grad: False
# Layer name: features.10.conv.1.1, Requires Grad: False
# Layer name: features.10.conv.2, Requires Grad: False
# Layer name: features.10.conv.3, Requires Grad: False
# Layer name: features.10.conv.3, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0.0, Requires Grad: False
# Layer name: features.11.conv.0.1, Requires Grad: False
# Layer name: features.11.conv.0.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1.0, Requires Grad: False
# Layer name: features.11.conv.1.1, Requires Grad: False
# Layer name: features.11.conv.1.1, Requires Grad: False
# Layer name: features.11.conv.2, Requires Grad: False
# Layer name: features.11.conv.3, Requires Grad: False
# Layer name: features.11.conv.3, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0.0, Requires Grad: False
# Layer name: features.12.conv.0.1, Requires Grad: False
# Layer name: features.12.conv.0.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1.0, Requires Grad: False
# Layer name: features.12.conv.1.1, Requires Grad: False
# Layer name: features.12.conv.1.1, Requires Grad: False
# Layer name: features.12.conv.2, Requires Grad: False
# Layer name: features.12.conv.3, Requires Grad: False
# Layer name: features.12.conv.3, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0.0, Requires Grad: False
# Layer name: features.13.conv.0.1, Requires Grad: False
# Layer name: features.13.conv.0.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1.0, Requires Grad: False
# Layer name: features.13.conv.1.1, Requires Grad: False
# Layer name: features.13.conv.1.1, Requires Grad: False
# Layer name: features.13.conv.2, Requires Grad: False
# Layer name: features.13.conv.3, Requires Grad: False
# Layer name: features.13.conv.3, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0.0, Requires Grad: False
# Layer name: features.14.conv.0.1, Requires Grad: False
# Layer name: features.14.conv.0.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1.0, Requires Grad: False
# Layer name: features.14.conv.1.1, Requires Grad: False
# Layer name: features.14.conv.1.1, Requires Grad: False
# Layer name: features.14.conv.2, Requires Grad: False
# Layer name: features.14.conv.3, Requires Grad: False
# Layer name: features.14.conv.3, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0.0, Requires Grad: False
# Layer name: features.15.conv.0.1, Requires Grad: False
# Layer name: features.15.conv.0.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1.0, Requires Grad: False
# Layer name: features.15.conv.1.1, Requires Grad: False
# Layer name: features.15.conv.1.1, Requires Grad: False
# Layer name: features.15.conv.2, Requires Grad: False
# Layer name: features.15.conv.3, Requires Grad: False
# Layer name: features.15.conv.3, Requires Grad: False
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0.0, Requires Grad: True
# Layer name: features.16.conv.0.1, Requires Grad: True
# Layer name: features.16.conv.0.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1.0, Requires Grad: True
# Layer name: features.16.conv.1.1, Requires Grad: True
# Layer name: features.16.conv.1.1, Requires Grad: True
# Layer name: features.16.conv.2, Requires Grad: True
# Layer name: features.16.conv.3, Requires Grad: True
# Layer name: features.16.conv.3, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0.0, Requires Grad: True
# Layer name: features.17.conv.0.1, Requires Grad: True
# Layer name: features.17.conv.0.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1.0, Requires Grad: True
# Layer name: features.17.conv.1.1, Requires Grad: True
# Layer name: features.17.conv.1.1, Requires Grad: True
# Layer name: features.17.conv.2, Requires Grad: True
# Layer name: features.17.conv.3, Requires Grad: True
# Layer name: features.17.conv.3, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18.0, Requires Grad: True
# Layer name: features.18.1, Requires Grad: True
# Layer name: features.18.1, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier.1, Requires Grad: True
# Layer name: classifier.1, Requires Grad: True

# %%
#unfreeze_layers_idx = [16, 17, 18]
#unfreeze_selective_layers_by_ids(model, unfreeze_layers_idx )

# %%
# adding own FC and classification layer.. these layer will be trained 
model.classifier = nn.Sequential(nn.Dropout(0.2),
                                 nn.Linear(1280, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 1024),
                                 nn.Linear(1024, 4),
                                 nn.LogSoftmax(dim=1))

# %%
show_layers(model)
# Out:
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: False
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: , Requires Grad: True
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: False
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features, Requires Grad: True
# Layer name: features.0, Requires Grad: False
# Layer name: features.0, Requires Grad: False
# Layer name: features.0, Requires Grad: False
# Layer name: features.0.0, Requires Grad: False
# Layer name: features.0.1, Requires Grad: False
# Layer name: features.0.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0, Requires Grad: False
# Layer name: features.1.conv.0.0, Requires Grad: False
# Layer name: features.1.conv.0.1, Requires Grad: False
# Layer name: features.1.conv.0.1, Requires Grad: False
# Layer name: features.1.conv.1, Requires Grad: False
# Layer name: features.1.conv.2, Requires Grad: False
# Layer name: features.1.conv.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0, Requires Grad: False
# Layer name: features.2.conv.0.0, Requires Grad: False
# Layer name: features.2.conv.0.1, Requires Grad: False
# Layer name: features.2.conv.0.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1, Requires Grad: False
# Layer name: features.2.conv.1.0, Requires Grad: False
# Layer name: features.2.conv.1.1, Requires Grad: False
# Layer name: features.2.conv.1.1, Requires Grad: False
# Layer name: features.2.conv.2, Requires Grad: False
# Layer name: features.2.conv.3, Requires Grad: False
# Layer name: features.2.conv.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0, Requires Grad: False
# Layer name: features.3.conv.0.0, Requires Grad: False
# Layer name: features.3.conv.0.1, Requires Grad: False
# Layer name: features.3.conv.0.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1, Requires Grad: False
# Layer name: features.3.conv.1.0, Requires Grad: False
# Layer name: features.3.conv.1.1, Requires Grad: False
# Layer name: features.3.conv.1.1, Requires Grad: False
# Layer name: features.3.conv.2, Requires Grad: False
# Layer name: features.3.conv.3, Requires Grad: False
# Layer name: features.3.conv.3, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0, Requires Grad: False
# Layer name: features.4.conv.0.0, Requires Grad: False
# Layer name: features.4.conv.0.1, Requires Grad: False
# Layer name: features.4.conv.0.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1, Requires Grad: False
# Layer name: features.4.conv.1.0, Requires Grad: False
# Layer name: features.4.conv.1.1, Requires Grad: False
# Layer name: features.4.conv.1.1, Requires Grad: False
# Layer name: features.4.conv.2, Requires Grad: False
# Layer name: features.4.conv.3, Requires Grad: False
# Layer name: features.4.conv.3, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0, Requires Grad: False
# Layer name: features.5.conv.0.0, Requires Grad: False
# Layer name: features.5.conv.0.1, Requires Grad: False
# Layer name: features.5.conv.0.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1, Requires Grad: False
# Layer name: features.5.conv.1.0, Requires Grad: False
# Layer name: features.5.conv.1.1, Requires Grad: False
# Layer name: features.5.conv.1.1, Requires Grad: False
# Layer name: features.5.conv.2, Requires Grad: False
# Layer name: features.5.conv.3, Requires Grad: False
# Layer name: features.5.conv.3, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0, Requires Grad: False
# Layer name: features.6.conv.0.0, Requires Grad: False
# Layer name: features.6.conv.0.1, Requires Grad: False
# Layer name: features.6.conv.0.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1, Requires Grad: False
# Layer name: features.6.conv.1.0, Requires Grad: False
# Layer name: features.6.conv.1.1, Requires Grad: False
# Layer name: features.6.conv.1.1, Requires Grad: False
# Layer name: features.6.conv.2, Requires Grad: False
# Layer name: features.6.conv.3, Requires Grad: False
# Layer name: features.6.conv.3, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0, Requires Grad: False
# Layer name: features.7.conv.0.0, Requires Grad: False
# Layer name: features.7.conv.0.1, Requires Grad: False
# Layer name: features.7.conv.0.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1, Requires Grad: False
# Layer name: features.7.conv.1.0, Requires Grad: False
# Layer name: features.7.conv.1.1, Requires Grad: False
# Layer name: features.7.conv.1.1, Requires Grad: False
# Layer name: features.7.conv.2, Requires Grad: False
# Layer name: features.7.conv.3, Requires Grad: False
# Layer name: features.7.conv.3, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0, Requires Grad: False
# Layer name: features.8.conv.0.0, Requires Grad: False
# Layer name: features.8.conv.0.1, Requires Grad: False
# Layer name: features.8.conv.0.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1, Requires Grad: False
# Layer name: features.8.conv.1.0, Requires Grad: False
# Layer name: features.8.conv.1.1, Requires Grad: False
# Layer name: features.8.conv.1.1, Requires Grad: False
# Layer name: features.8.conv.2, Requires Grad: False
# Layer name: features.8.conv.3, Requires Grad: False
# Layer name: features.8.conv.3, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0, Requires Grad: False
# Layer name: features.9.conv.0.0, Requires Grad: False
# Layer name: features.9.conv.0.1, Requires Grad: False
# Layer name: features.9.conv.0.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1, Requires Grad: False
# Layer name: features.9.conv.1.0, Requires Grad: False
# Layer name: features.9.conv.1.1, Requires Grad: False
# Layer name: features.9.conv.1.1, Requires Grad: False
# Layer name: features.9.conv.2, Requires Grad: False
# Layer name: features.9.conv.3, Requires Grad: False
# Layer name: features.9.conv.3, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0, Requires Grad: False
# Layer name: features.10.conv.0.0, Requires Grad: False
# Layer name: features.10.conv.0.1, Requires Grad: False
# Layer name: features.10.conv.0.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1, Requires Grad: False
# Layer name: features.10.conv.1.0, Requires Grad: False
# Layer name: features.10.conv.1.1, Requires Grad: False
# Layer name: features.10.conv.1.1, Requires Grad: False
# Layer name: features.10.conv.2, Requires Grad: False
# Layer name: features.10.conv.3, Requires Grad: False
# Layer name: features.10.conv.3, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0, Requires Grad: False
# Layer name: features.11.conv.0.0, Requires Grad: False
# Layer name: features.11.conv.0.1, Requires Grad: False
# Layer name: features.11.conv.0.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1, Requires Grad: False
# Layer name: features.11.conv.1.0, Requires Grad: False
# Layer name: features.11.conv.1.1, Requires Grad: False
# Layer name: features.11.conv.1.1, Requires Grad: False
# Layer name: features.11.conv.2, Requires Grad: False
# Layer name: features.11.conv.3, Requires Grad: False
# Layer name: features.11.conv.3, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0, Requires Grad: False
# Layer name: features.12.conv.0.0, Requires Grad: False
# Layer name: features.12.conv.0.1, Requires Grad: False
# Layer name: features.12.conv.0.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1, Requires Grad: False
# Layer name: features.12.conv.1.0, Requires Grad: False
# Layer name: features.12.conv.1.1, Requires Grad: False
# Layer name: features.12.conv.1.1, Requires Grad: False
# Layer name: features.12.conv.2, Requires Grad: False
# Layer name: features.12.conv.3, Requires Grad: False
# Layer name: features.12.conv.3, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0, Requires Grad: False
# Layer name: features.13.conv.0.0, Requires Grad: False
# Layer name: features.13.conv.0.1, Requires Grad: False
# Layer name: features.13.conv.0.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1, Requires Grad: False
# Layer name: features.13.conv.1.0, Requires Grad: False
# Layer name: features.13.conv.1.1, Requires Grad: False
# Layer name: features.13.conv.1.1, Requires Grad: False
# Layer name: features.13.conv.2, Requires Grad: False
# Layer name: features.13.conv.3, Requires Grad: False
# Layer name: features.13.conv.3, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0, Requires Grad: False
# Layer name: features.14.conv.0.0, Requires Grad: False
# Layer name: features.14.conv.0.1, Requires Grad: False
# Layer name: features.14.conv.0.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1, Requires Grad: False
# Layer name: features.14.conv.1.0, Requires Grad: False
# Layer name: features.14.conv.1.1, Requires Grad: False
# Layer name: features.14.conv.1.1, Requires Grad: False
# Layer name: features.14.conv.2, Requires Grad: False
# Layer name: features.14.conv.3, Requires Grad: False
# Layer name: features.14.conv.3, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0, Requires Grad: False
# Layer name: features.15.conv.0.0, Requires Grad: False
# Layer name: features.15.conv.0.1, Requires Grad: False
# Layer name: features.15.conv.0.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1, Requires Grad: False
# Layer name: features.15.conv.1.0, Requires Grad: False
# Layer name: features.15.conv.1.1, Requires Grad: False
# Layer name: features.15.conv.1.1, Requires Grad: False
# Layer name: features.15.conv.2, Requires Grad: False
# Layer name: features.15.conv.3, Requires Grad: False
# Layer name: features.15.conv.3, Requires Grad: False
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0, Requires Grad: True
# Layer name: features.16.conv.0.0, Requires Grad: True
# Layer name: features.16.conv.0.1, Requires Grad: True
# Layer name: features.16.conv.0.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1, Requires Grad: True
# Layer name: features.16.conv.1.0, Requires Grad: True
# Layer name: features.16.conv.1.1, Requires Grad: True
# Layer name: features.16.conv.1.1, Requires Grad: True
# Layer name: features.16.conv.2, Requires Grad: True
# Layer name: features.16.conv.3, Requires Grad: True
# Layer name: features.16.conv.3, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0, Requires Grad: True
# Layer name: features.17.conv.0.0, Requires Grad: True
# Layer name: features.17.conv.0.1, Requires Grad: True
# Layer name: features.17.conv.0.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1, Requires Grad: True
# Layer name: features.17.conv.1.0, Requires Grad: True
# Layer name: features.17.conv.1.1, Requires Grad: True
# Layer name: features.17.conv.1.1, Requires Grad: True
# Layer name: features.17.conv.2, Requires Grad: True
# Layer name: features.17.conv.3, Requires Grad: True
# Layer name: features.17.conv.3, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18, Requires Grad: True
# Layer name: features.18.0, Requires Grad: True
# Layer name: features.18.1, Requires Grad: True
# Layer name: features.18.1, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier, Requires Grad: True
# Layer name: classifier.1, Requires Grad: True
# Layer name: classifier.1, Requires Grad: True
# Layer name: classifier.4, Requires Grad: True
# Layer name: classifier.4, Requires Grad: True
# Layer name: classifier.5, Requires Grad: True
# Layer name: classifier.5, Requires Grad: True

# %%
from torchsummary import summary
model_name = "MobileNet_V2"
model = model.to(device)
summary(model, input_size=(3,224,224))
#print(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
#       BatchNorm2d-14           [-1, 96, 56, 56]             192
#             ReLU6-15           [-1, 96, 56, 56]               0
#            Conv2d-16           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-17           [-1, 24, 56, 56]              48
#  InvertedResidual-18           [-1, 24, 56, 56]               0
#            Conv2d-19          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-20          [-1, 144, 56, 56]             288
#             ReLU6-21          [-1, 144, 56, 56]               0
#            Conv2d-22          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-23          [-1, 144, 56, 56]             288
#             ReLU6-24          [-1, 144, 56, 56]               0
#            Conv2d-25           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-26           [-1, 24, 56, 56]              48
#  InvertedResidual-27           [-1, 24, 56, 56]               0
#            Conv2d-28          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-29          [-1, 144, 56, 56]             288
#             ReLU6-30          [-1, 144, 56, 56]               0
#            Conv2d-31          [-1, 144, 28, 28]           1,296
#       BatchNorm2d-32          [-1, 144, 28, 28]             288
#             ReLU6-33          [-1, 144, 28, 28]               0
#            Conv2d-34           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-35           [-1, 32, 28, 28]              64
#  InvertedResidual-36           [-1, 32, 28, 28]               0
#            Conv2d-37          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-38          [-1, 192, 28, 28]             384
#             ReLU6-39          [-1, 192, 28, 28]               0
#            Conv2d-40          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-41          [-1, 192, 28, 28]             384
#             ReLU6-42          [-1, 192, 28, 28]               0
#            Conv2d-43           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-44           [-1, 32, 28, 28]              64
#  InvertedResidual-45           [-1, 32, 28, 28]               0
#            Conv2d-46          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-47          [-1, 192, 28, 28]             384
#             ReLU6-48          [-1, 192, 28, 28]               0
#            Conv2d-49          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-50          [-1, 192, 28, 28]             384
#             ReLU6-51          [-1, 192, 28, 28]               0
#            Conv2d-52           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-53           [-1, 32, 28, 28]              64
#  InvertedResidual-54           [-1, 32, 28, 28]               0
#            Conv2d-55          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-56          [-1, 192, 28, 28]             384
#             ReLU6-57          [-1, 192, 28, 28]               0
#            Conv2d-58          [-1, 192, 14, 14]           1,728
#       BatchNorm2d-59          [-1, 192, 14, 14]             384
#             ReLU6-60          [-1, 192, 14, 14]               0
#            Conv2d-61           [-1, 64, 14, 14]          12,288
#       BatchNorm2d-62           [-1, 64, 14, 14]             128
#  InvertedResidual-63           [-1, 64, 14, 14]               0
#            Conv2d-64          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-65          [-1, 384, 14, 14]             768
#             ReLU6-66          [-1, 384, 14, 14]               0
#            Conv2d-67          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-68          [-1, 384, 14, 14]             768
#             ReLU6-69          [-1, 384, 14, 14]               0
#            Conv2d-70           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-71           [-1, 64, 14, 14]             128
#  InvertedResidual-72           [-1, 64, 14, 14]               0
#            Conv2d-73          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-74          [-1, 384, 14, 14]             768
#             ReLU6-75          [-1, 384, 14, 14]               0
#            Conv2d-76          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-77          [-1, 384, 14, 14]             768
#             ReLU6-78          [-1, 384, 14, 14]               0
#            Conv2d-79           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-80           [-1, 64, 14, 14]             128
#  InvertedResidual-81           [-1, 64, 14, 14]               0
#            Conv2d-82          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-83          [-1, 384, 14, 14]             768
#             ReLU6-84          [-1, 384, 14, 14]               0
#            Conv2d-85          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-86          [-1, 384, 14, 14]             768
#             ReLU6-87          [-1, 384, 14, 14]               0
#            Conv2d-88           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-89           [-1, 64, 14, 14]             128
#  InvertedResidual-90           [-1, 64, 14, 14]               0
#            Conv2d-91          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-92          [-1, 384, 14, 14]             768
#             ReLU6-93          [-1, 384, 14, 14]               0
#            Conv2d-94          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-95          [-1, 384, 14, 14]             768
#             ReLU6-96          [-1, 384, 14, 14]               0
#            Conv2d-97           [-1, 96, 14, 14]          36,864
#       BatchNorm2d-98           [-1, 96, 14, 14]             192
#  InvertedResidual-99           [-1, 96, 14, 14]               0
#           Conv2d-100          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-101          [-1, 576, 14, 14]           1,152
#            ReLU6-102          [-1, 576, 14, 14]               0
#           Conv2d-103          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-104          [-1, 576, 14, 14]           1,152
#            ReLU6-105          [-1, 576, 14, 14]               0
#           Conv2d-106           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-107           [-1, 96, 14, 14]             192
# InvertedResidual-108           [-1, 96, 14, 14]               0
#           Conv2d-109          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-110          [-1, 576, 14, 14]           1,152
#            ReLU6-111          [-1, 576, 14, 14]               0
#           Conv2d-112          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-113          [-1, 576, 14, 14]           1,152
#            ReLU6-114          [-1, 576, 14, 14]               0
#           Conv2d-115           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-116           [-1, 96, 14, 14]             192
# InvertedResidual-117           [-1, 96, 14, 14]               0
#           Conv2d-118          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-119          [-1, 576, 14, 14]           1,152
#            ReLU6-120          [-1, 576, 14, 14]               0
#           Conv2d-121            [-1, 576, 7, 7]           5,184
#      BatchNorm2d-122            [-1, 576, 7, 7]           1,152
#            ReLU6-123            [-1, 576, 7, 7]               0
#           Conv2d-124            [-1, 160, 7, 7]          92,160
#      BatchNorm2d-125            [-1, 160, 7, 7]             320
# InvertedResidual-126            [-1, 160, 7, 7]               0
#           Conv2d-127            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-128            [-1, 960, 7, 7]           1,920
#            ReLU6-129            [-1, 960, 7, 7]               0
#           Conv2d-130            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-131            [-1, 960, 7, 7]           1,920
#            ReLU6-132            [-1, 960, 7, 7]               0
#           Conv2d-133            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-134            [-1, 160, 7, 7]             320
# InvertedResidual-135            [-1, 160, 7, 7]               0
#           Conv2d-136            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-137            [-1, 960, 7, 7]           1,920
#            ReLU6-138            [-1, 960, 7, 7]               0
#           Conv2d-139            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-140            [-1, 960, 7, 7]           1,920
#            ReLU6-141            [-1, 960, 7, 7]               0
#           Conv2d-142            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-143            [-1, 160, 7, 7]             320
# InvertedResidual-144            [-1, 160, 7, 7]               0
#           Conv2d-145            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-146            [-1, 960, 7, 7]           1,920
#            ReLU6-147            [-1, 960, 7, 7]               0
#           Conv2d-148            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-149            [-1, 960, 7, 7]           1,920
#            ReLU6-150            [-1, 960, 7, 7]               0
#           Conv2d-151            [-1, 320, 7, 7]         307,200
#      BatchNorm2d-152            [-1, 320, 7, 7]             640
# InvertedResidual-153            [-1, 320, 7, 7]               0
#           Conv2d-154           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-155           [-1, 1280, 7, 7]           2,560
#            ReLU6-156           [-1, 1280, 7, 7]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                  [-1, 512]         655,872
#             ReLU-159                  [-1, 512]               0
#          Dropout-160                  [-1, 512]               0
#           Linear-161                 [-1, 1024]         525,312
#           Linear-162                    [-1, 4]           4,100
#       LogSoftmax-163                    [-1, 4]               0
# ================================================================
# Total params: 3,409,156
# Trainable params: 2,391,364
# Non-trainable params: 1,017,792
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.88
# Params size (MB): 13.00
# Estimated Total Size (MB): 166.46
# ----------------------------------------------------------------

# %% [markdown]
# ## LR Finder
#
# The model is trained for num_iter iterations while the learning rate is increased from its initial value specified by the optimizer algorithm to end_lr. The increase can be linear (step_mode="linear") or exponential (step_mode="exp"); linear provides good results for small ranges while exponential is recommended for larger ranges

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-7, momentum=0.9, weight_decay=1e-4)
lr_finder = LRFinder(model, optimizer, criterion, device=device)
lr_finder.range_test(train_loader, end_lr=100, num_iter=200, step_mode="exp")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
# Note that the loss in the loss vs. learning rate plot is the training loss.
lr_finder.plot()

# %%
# To restore the model and optimizer to their initial state
lr_finder.reset()

'''
Here model is evaluated on that validation dataset after each iteration.
The evaluation loss is more sensitive to instability therefore it provides a more precise view of when the divergence occurs. 
The disadvantage is that it takes significantly longer to run
'''
lr_finder.range_test(train_loader, val_loader=test_loader, end_lr=100, num_iter=200, step_mode="exp")

# %%
# Note that the loss in the loss vs. learning rate plot is the validation loss.
lr_finder.plot()

# %% [markdown]
# ## Build and train model

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau
import torch.nn.functional as F

EPOCHS = config_params['epochs']
max_lr = 0.1   # maximum LR 
min_lr = 1e-3   # minimum LR 
L2_val = 1e-4 # L2 Regularization
start_epoch = 1
step_size = 8 # num of epoch, if LR is update epoch wise
if config_params["lr_update_ty"] == LR_UPDATE_TY.BATCHWISE:
  step_size = 2000

#criterion = F.nll_loss()
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(model.parameters(), lr=min_lr, momemtum=0.9, nesterov=True, weight_decay=L2_val) 
optimizer = optim.SGD(model.parameters(), lr=min_lr, momentum=0.9, nesterov=True, weight_decay=L2_val)  

# CyclicLR- use one cycle policy: MAX-LR at epoch=5, Triangular policy
lr_scheduler = CyclicLR(optimizer, base_lr=min_lr, max_lr=max_lr, step_size_up=step_size, step_size_down=step_size, mode='triangular2', last_epoch=-1)

# reduce LR when modle get stuck in plateu region
reduceLr_scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, threshold=0.001)

# %%
import utils.model_utils as mutils_fxn

# if resuming the traning then load the model, update optimizer states and loss state
if config_params["resume_training"] == True:
  print("This is resuming the training session...")
  model, optimizer, start_epoch, criterion = mutils_fxn.load_checkpoint(model, optimizer, device, config_params["load_model_path"])
else:
  print("This is fresh attempt training ...")
# Out:
# This is fresh attempt training ...

# %%
from utils.model_utils import ModelUtils
mutils = ModelUtils(model, 
                    device, 
                    train_loader=train_loader, 
                    test_loader=test_loader, 
                    start_epoch = start_epoch,
                    epochs=EPOCHS,
                    criterion=criterion, 
                    optimizer=optimizer,
                    lr_scheduler=lr_scheduler,
                    lr_update_ty=config_params['lr_update_ty'],
                    reduceLr_scheduler=reduceLr_scheduler,
                    saved_model_dir=SAVED_MODELS_DIR)

# %%
m_history = mutils.build()
# Out:
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 1 TRAIN ==> [Batch=107] train_loss=1.043396 train_acc: 54.42 LR=0.001: 100%|██████████| 107/107 [03:31<00:00,  1.98s/it]
# Epoch: 1 TEST  ==> [Batch=46] test_loss=0.666595 test_acc: 76.77: 100%|██████████| 46/46 [01:23<00:00,  1.81s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 2 TRAIN ==> [Batch=107] train_loss=0.447708 train_acc: 82.30 LR=0.013375000000000001: 100%|██████████| 107/107 [03:29<00:00,  1.96s/it]
# Epoch: 2 TEST  ==> [Batch=46] test_loss=0.340552 test_acc: 86.99: 100%|██████████| 46/46 [01:22<00:00,  1.79s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 3 TRAIN ==> [Batch=107] train_loss=0.374549 train_acc: 85.01 LR=0.025750000000000002: 100%|██████████| 107/107 [03:26<00:00,  1.93s/it]
# Epoch: 3 TEST  ==> [Batch=46] test_loss=0.341593 test_acc: 87.27: 100%|██████████| 46/46 [01:22<00:00,  1.79s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 4 TRAIN ==> [Batch=107] train_loss=0.351534 train_acc: 86.14 LR=0.038125000000000006: 100%|██████████| 107/107 [03:25<00:00,  1.92s/it]
# Epoch: 4 TEST  ==> [Batch=46] test_loss=0.361852 test_acc: 86.70: 100%|██████████| 46/46 [01:21<00:00,  1.78s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 5 TRAIN ==> [Batch=107] train_loss=0.325088 train_acc: 87.34 LR=0.0505: 100%|██████████| 107/107 [03:27<00:00,  1.94s/it]
# Epoch: 5 TEST  ==> [Batch=46] test_loss=0.365963 test_acc: 85.98: 100%|██████████| 46/46 [01:24<00:00,  1.84s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 6 TRAIN ==> [Batch=107] train_loss=0.301477 train_acc: 88.09 LR=0.062875: 100%|██████████| 107/107 [03:30<00:00,  1.97s/it]
# Epoch: 6 TEST  ==> [Batch=46] test_loss=0.352466 test_acc: 87.13: 100%|██████████| 46/46 [01:22<00:00,  1.79s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 7 TRAIN ==> [Batch=107] train_loss=0.299991 train_acc: 88.38 LR=0.07525000000000001: 100%|██████████| 107/107 [03:24<00:00,  1.91s/it]
# Epoch: 7 TEST  ==> [Batch=46] test_loss=0.361767 test_acc: 86.26: 100%|██████████| 46/46 [01:21<00:00,  1.77s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 8 TRAIN ==> [Batch=107] train_loss=0.227344 train_acc: 91.29 LR=0.008762500000000001: 100%|██████████| 107/107 [03:27<00:00,  1.94s/it]
# Epoch: 8 TEST  ==> [Batch=46] test_loss=0.314864 test_acc: 88.93: 100%|██████████| 46/46 [01:22<00:00,  1.80s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 9 TRAIN ==> [Batch=107] train_loss=0.277162 train_acc: 89.05 LR=0.1: 100%|██████████| 107/107 [03:27<00:00,  1.94s/it]
# Epoch: 9 TEST  ==> [Batch=46] test_loss=0.322204 test_acc: 87.73: 100%|██████████| 46/46 [01:23<00:00,  1.82s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 10 TRAIN ==> [Batch=107] train_loss=0.261591 train_acc: 89.82 LR=0.08762500000000001: 100%|██████████| 107/107 [03:33<00:00,  1.99s/it]
# Epoch: 10 TEST  ==> [Batch=46] test_loss=0.378932 test_acc: 86.70: 100%|██████████| 46/46 [01:23<00:00,  1.81s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 11 TRAIN ==> [Batch=107] train_loss=0.237132 train_acc: 90.88 LR=0.07525000000000001: 100%|██████████| 107/107 [03:36<00:00,  2.02s/it]
# Epoch: 11 TEST  ==> [Batch=46] test_loss=0.343512 test_acc: 87.17: 100%|██████████| 46/46 [01:25<00:00,  1.85s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 12 TRAIN ==> [Batch=107] train_loss=0.210681 train_acc: 91.71 LR=0.062875: 100%|██████████| 107/107 [03:32<00:00,  1.98s/it]
# Epoch: 12 TEST  ==> [Batch=46] test_loss=0.353647 test_acc: 87.97: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 13 TRAIN ==> [Batch=107] train_loss=0.191854 train_acc: 92.43 LR=0.0505: 100%|██████████| 107/107 [03:33<00:00,  2.00s/it]
# Epoch: 13 TEST  ==> [Batch=46] test_loss=0.388535 test_acc: 87.89: 100%|██████████| 46/46 [01:26<00:00,  1.87s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 14 TRAIN ==> [Batch=107] train_loss=0.147206 train_acc: 94.50 LR=0.003812500000000001: 100%|██████████| 107/107 [03:32<00:00,  1.99s/it]
# Epoch: 14 TEST  ==> [Batch=46] test_loss=0.368091 test_acc: 88.57: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 15 TRAIN ==> [Batch=107] train_loss=0.149375 train_acc: 94.18 LR=0.025750000000000002: 100%|██████████| 107/107 [03:35<00:00,  2.02s/it]
# Epoch: 15 TEST  ==> [Batch=46] test_loss=0.397863 test_acc: 88.06: 100%|██████████| 46/46 [01:26<00:00,  1.87s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 16 TRAIN ==> [Batch=107] train_loss=0.124452 train_acc: 95.20 LR=0.013375000000000001: 100%|██████████| 107/107 [03:32<00:00,  1.99s/it]
# Epoch: 16 TEST  ==> [Batch=46] test_loss=0.400149 test_acc: 88.28: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 17 TRAIN ==> [Batch=107] train_loss=0.096859 train_acc: 96.36 LR=0.001: 100%|██████████| 107/107 [03:33<00:00,  2.00s/it]
# Epoch: 17 TEST  ==> [Batch=46] test_loss=0.424944 test_acc: 88.69: 100%|██████████| 46/46 [01:26<00:00,  1.88s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 18 TRAIN ==> [Batch=107] train_loss=0.099584 train_acc: 96.10 LR=0.0071875: 100%|██████████| 107/107 [03:35<00:00,  2.01s/it]
# Epoch: 18 TEST  ==> [Batch=46] test_loss=0.457538 test_acc: 88.09: 100%|██████████| 46/46 [01:25<00:00,  1.87s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 19 TRAIN ==> [Batch=107] train_loss=0.086307 train_acc: 96.54 LR=0.0013375000000000001: 100%|██████████| 107/107 [03:34<00:00,  2.01s/it]
# Epoch: 19 TEST  ==> [Batch=46] test_loss=0.462971 test_acc: 88.88: 100%|██████████| 46/46 [01:25<00:00,  1.87s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 20 TRAIN ==> [Batch=107] train_loss=0.115475 train_acc: 95.49 LR=0.019562500000000003: 100%|██████████| 107/107 [03:37<00:00,  2.04s/it]
# Epoch: 20 TEST  ==> [Batch=46] test_loss=0.435618 test_acc: 88.19: 100%|██████████| 46/46 [01:26<00:00,  1.89s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 21 TRAIN ==> [Batch=107] train_loss=0.121276 train_acc: 95.24 LR=0.025750000000000002: 100%|██████████| 107/107 [03:36<00:00,  2.02s/it]
# Epoch: 21 TEST  ==> [Batch=46] test_loss=0.435145 test_acc: 88.13: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 22 TRAIN ==> [Batch=107] train_loss=0.131689 train_acc: 95.19 LR=0.0319375: 100%|██████████| 107/107 [03:30<00:00,  1.97s/it]
# Epoch: 22 TEST  ==> [Batch=46] test_loss=0.413368 test_acc: 88.86: 100%|██████████| 46/46 [01:26<00:00,  1.88s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 23 TRAIN ==> [Batch=107] train_loss=0.147194 train_acc: 94.38 LR=0.038125000000000006: 100%|██████████| 107/107 [03:34<00:00,  2.00s/it]
# Epoch: 23 TEST  ==> [Batch=46] test_loss=0.504053 test_acc: 85.52: 100%|██████████| 46/46 [01:26<00:00,  1.87s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 24 TRAIN ==> [Batch=107] train_loss=0.108093 train_acc: 95.99 LR=0.00443125: 100%|██████████| 107/107 [03:34<00:00,  2.00s/it]
# Epoch: 24 TEST  ==> [Batch=46] test_loss=0.424683 test_acc: 88.71: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 25 TRAIN ==> [Batch=107] train_loss=0.135990 train_acc: 94.79 LR=0.0505: 100%|██████████| 107/107 [03:34<00:00,  2.00s/it]
# Epoch: 25 TEST  ==> [Batch=46] test_loss=0.557631 test_acc: 87.03: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 26 TRAIN ==> [Batch=107] train_loss=0.140779 train_acc: 94.82 LR=0.044312500000000005: 100%|██████████| 107/107 [03:34<00:00,  2.01s/it]
# Epoch: 26 TEST  ==> [Batch=46] test_loss=0.477627 test_acc: 86.46: 100%|██████████| 46/46 [01:27<00:00,  1.91s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 27 TRAIN ==> [Batch=107] train_loss=0.123286 train_acc: 95.21 LR=0.038125000000000006: 100%|██████████| 107/107 [03:33<00:00,  2.00s/it]
# Epoch: 27 TEST  ==> [Batch=46] test_loss=0.433247 test_acc: 88.57: 100%|██████████| 46/46 [01:26<00:00,  1.89s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 28 TRAIN ==> [Batch=107] train_loss=0.109649 train_acc: 95.83 LR=0.0319375: 100%|██████████| 107/107 [03:34<00:00,  2.00s/it]
# Epoch: 28 TEST  ==> [Batch=46] test_loss=0.430106 test_acc: 88.23: 100%|██████████| 46/46 [01:25<00:00,  1.86s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 29 TRAIN ==> [Batch=107] train_loss=0.083841 train_acc: 96.95 LR=0.0025750000000000005: 100%|██████████| 107/107 [03:35<00:00,  2.02s/it]
# Epoch: 29 TEST  ==> [Batch=46] test_loss=0.446245 test_acc: 88.88: 100%|██████████| 46/46 [01:24<00:00,  1.84s/it]
#   0%|          | 0/107 [00:00<?, ?it/s]
# /n
# Epoch: 30 TRAIN ==> [Batch=107] train_loss=0.078278 train_acc: 97.03 LR=0.019562500000000003: 100%|██████████| 107/107 [03:34<00:00,  2.01s/it]
# Epoch: 30 TEST  ==> [Batch=46] test_loss=0.492022 test_acc: 88.26: 100%|██████████| 46/46 [01:25<00:00,  1.87s/it]

# %%
#model = torch.load(f'{SAVED_MODELS_DIR}/s2_model_ts1595654468.113072.pt')

# %%
import utils.model_utils as mutils_fxn
testacc, testsize = mutils_fxn.get_test_accuracy(model, device, test_loader)
print(f'Accuracy of the model on the {testsize} test images: {testacc:0.2f}%')
# Out:
# Accuracy of the model on the 5828 test images: 88.26%

# %%
mutils_fxn.get_class_based_accuracy(model, device, test_loader, class_list)
# Out:
# Accuracy of Flying Birds : 97.33%
# Accuracy of Large QuadCopters : 76.32%
# Accuracy of Small QuadCopters : 81.82%
# Accuracy of Winged Drones : 92.11%

# %%
# Accurracy and loss history plot
m_history.plot_history(title=model_name, save_filename=f'{PLOT_DIR}/model_history.jpg')

# %%
import time
torch.save(model, f'{SAVED_MODELS_DIR}/s2_model_ep30_ts{time.time()}.pt')
#torch.save(model, f'{SAVED_MODELS_DIR}/s2_model_epoch10.pt')

# %% [markdown]
# # Visualize few misclassified images

# %%
# %%time
print('Ploting misclassified images:\n')

print('Abbrevation used: \nT: Target, P: Prediction')
display_classnames(class_list_shortname, class_list)
print('\n')
for idx, name in enumerate(class_list):
  print(f'Misclassification for {name}..')
  putils.plot_misclassified_images_for_class(model, 
                                             testloader=test_loader, 
                                              classid=idx,
                                              figsize=(30,3),
                                              num_of_images=10, nrow=1, 
                                              save_filename=f'{PLOT_DIR}/{name}_misclassified_images.jpg')
# Out:
# Ploting misclassified images:
#
# Abbrevation used:
# T: Target, P: Prediction
# FB: Flying Birds
# LQC: Large QuadCopters
# SQC: Small QuadCopters
# WD: Winged Drones
#
#
# Misclassification for Flying Birds..
# Misclassification for Large QuadCopters..
# Misclassification for Small QuadCopters..
# Misclassification for Winged Drones..
# CPU times: user 2.73 s, sys: 1.78 s, total: 4.51 s
# Wall time: 2min 7s
